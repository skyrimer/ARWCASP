# %%
import pandas as pd
import matplotlib.pyplot as plt
import geopandas as gpd

#deprivation_index_2015 = pd.read_parquet("../processed_data/deprivation_2015.parquet")

deprivation_index = pd.read_parquet("../processed_data/deprivation_index.parquet")

big_dataset = pd.read_parquet("../processed_data/lsoa_data2.parquet")

deprivation_index
# Out:
#          ls11cd                la19nm  england_imd_rank  england_imd_decile  \
# 0     E01000001        City of London             29199                   9
# 1     E01000002        City of London             30379                  10
# 2     E01000003        City of London             14915                   5
# 3     E01000005        City of London              8678                   3
# 4     E01000006  Barking and Dagenham             14486                   5
# ...         ...                   ...               ...                 ...
# 4830  E01033742             Greenwich             20945                   7
# 4831  E01033743             Greenwich             13578                   5
# 4832  E01033744             Greenwich              8319                   3
# 4833  E01033745             Greenwich             12697                   4
# 4834  E01033746             Greenwich             12902                   4
#
# ...

# %%
# remove the name
deprivation_index = deprivation_index.drop(['la19nm'], axis=1)
deprivation_index
# Out:
#          ls11cd  england_imd_rank  england_imd_decile  london_imd_rank  \
# 0     E01000001             29199                   9             4576
# 1     E01000002             30379                  10             4700
# 2     E01000003             14915                   5             2562
# 3     E01000005              8678                   3             1325
# 4     E01000006             14486                   5             2485
# ...         ...               ...                 ...              ...
# 4830  E01033742             20945                   7             3538
# 4831  E01033743             13578                   5             2347
# 4832  E01033744              8319                   3             1235
# 4833  E01033745             12697                   4             2184
# 4834  E01033746             12902                   4             2227
#
#       london_imd_decile IDAOP_london_rank  IDAOP_london_decile  \
# ...

# %%
# all of the columns present
print(list(deprivation_index.columns))
# Out:
# ['ls11cd', 'england_imd_rank', 'england_imd_decile', 'london_imd_rank', 'london_imd_decile', 'IDAOP_london_rank', 'IDAOP_london_decile', 'IDACI_london_rank', 'IDACI_london_decile', 'Income_london_rank', 'Income_london_decile', 'employment_london_rank', 'employment_london_decile', 'crime_london_rank', 'crime_london_decile', 'barriers_london_rank', 'barriers_london_decile', 'livingEnv_london_rank', 'livingEnv_london_decile', 'health_london_rank', 'health_london_decile', 'edu_london_rank', 'edu_london_decile']

# %%
deprivation_index_2015
# Out:
#       LSOA code (2011) LSOA name (2011) Local Authority District code (2013)  \
# 0            E01031349        Adur 001A                            E07000223
# 1            E01031350        Adur 001B                            E07000223
# 2            E01031351        Adur 001C                            E07000223
# 3            E01031352        Adur 001D                            E07000223
# 4            E01031370        Adur 001E                            E07000223
# ...                ...              ...                                  ...
# 32839        E01013341        York 024B                            E06000014
# 32840        E01013342        York 024C                            E06000014
# 32841        E01013423        York 024D                            E06000014
# 32842        E01013424        York 024E                            E06000014
# 32843        E01013425        York 024F                            E06000014
#
# ...

# %%
# Only keep the rows relevant to London

# Get the unique Lsoa codes from df_lsoa_codes
lsoa_codes_to_keep = deprivation_index['ls11cd'].unique()

deprivation_index_2015_filtered = deprivation_index_2015[deprivation_index_2015['LSOA code (2011)'].isin(lsoa_codes_to_keep)]
deprivation_index_2015_filtered = deprivation_index_2015_filtered.reset_index().drop(columns='index')

deprivation_index_2015_filtered
# Out:
#      LSOA code (2011)           LSOA name (2011)  \
# 0           E01000027  Barking and Dagenham 001A
# 1           E01000028  Barking and Dagenham 001B
# 2           E01000029  Barking and Dagenham 001C
# 3           E01000030  Barking and Dagenham 001D
# 4           E01000031  Barking and Dagenham 002A
# ...               ...                        ...
# 4830        E01004669           Westminster 024B
# 4831        E01004737           Westminster 024C
# 4832        E01004738           Westminster 024D
# 4833        E01004739           Westminster 024E
# 4834        E01004741           Westminster 024F
#
#      Local Authority District code (2013)  \
# 0                               E09000002
# 1                               E09000002
# 2                               E09000002
# 3                               E09000002
# 4                               E09000002
# ...                                   ...
# 4830                            E09000033
# ...

# %%
deprivation_index_2015_filtered.to_parquet("../processed_data/filtered_deprivation_2015.parquet", index=False)

# %%
big_dataset
# Out:
#      ﻿|Level2_0|Codes     ﻿|Level2_1|Names  \
# 0           E01000907          Camden 001A
# 1           E01000908          Camden 001B
# 2           E01000909          Camden 001C
# 3           E01000912          Camden 001D
# 4           E01000913          Camden 001E
# ...               ...                  ...
# 4831        E01004329  Waltham Forest 028C
# 4832        E01004330  Waltham Forest 028D
# 4833        E01004331  Waltham Forest 028E
# 4834        E01004332  Waltham Forest 028F
# 4835             None                 None
#
#       Adults in Employment|No adults in employment in household: With dependent children|2011  \
# 0                                                  65.0
# 1                                                  41.0
# 2                                                  16.0
# 3                                                  49.0
# 4                                                   6.0
# ...                                                 ...
# ...

# %%
import pandas as pd

deprivation_2015 = pd.read_parquet("../processed_data/filtered_deprivation_2015.parquet")
deprivation_2015
# Out:
#      LSOA code (2011)           LSOA name (2011)  \
# 0           E01000027  Barking and Dagenham 001A
# 1           E01000028  Barking and Dagenham 001B
# 2           E01000029  Barking and Dagenham 001C
# 3           E01000030  Barking and Dagenham 001D
# 4           E01000031  Barking and Dagenham 002A
# ...               ...                        ...
# 4830        E01004669           Westminster 024B
# 4831        E01004737           Westminster 024C
# 4832        E01004738           Westminster 024D
# 4833        E01004739           Westminster 024E
# 4834        E01004741           Westminster 024F
#
#      Local Authority District code (2013)  \
# 0                               E09000002
# 1                               E09000002
# 2                               E09000002
# 3                               E09000002
# 4                               E09000002
# ...                                   ...
# 4830                            E09000033
# ...

# %%
deprivation_2015.drop(columns=['Local Authority District code (2013)'])
# Out:
#      LSOA code (2011)           LSOA name (2011)  \
# 0           E01000027  Barking and Dagenham 001A
# 1           E01000028  Barking and Dagenham 001B
# 2           E01000029  Barking and Dagenham 001C
# 3           E01000030  Barking and Dagenham 001D
# 4           E01000031  Barking and Dagenham 002A
# ...               ...                        ...
# 4830        E01004669           Westminster 024B
# 4831        E01004737           Westminster 024C
# 4832        E01004738           Westminster 024D
# 4833        E01004739           Westminster 024E
# 4834        E01004741           Westminster 024F
#
#      Local Authority District name (2013)  \
# 0                    Barking and Dagenham
# 1                    Barking and Dagenham
# 2                    Barking and Dagenham
# 3                    Barking and Dagenham
# 4                    Barking and Dagenham
# ...                                   ...
# 4830                          Westminster
# ...

# %%
print(list(deprivation_2015.columns))
# Out:
# ['LSOA code (2011)', 'LSOA name (2011)', 'Local Authority District code (2013)', 'Local Authority District name (2013)', 'Index of Multiple Deprivation (IMD) Rank (where 1 is most deprived)', 'Index of Multiple Deprivation (IMD) Decile (where 1 is most deprived 10% of LSOAs)', 'Income Rank (where 1 is most deprived)', 'Income Decile (where 1 is most deprived 10% of LSOAs)', 'Employment Rank (where 1 is most deprived)', 'Employment Decile (where 1 is most deprived 10% of LSOAs)', 'Education, Skills and Training Rank (where 1 is most deprived)', 'Education, Skills and Training Decile (where 1 is most deprived 10% of LSOAs)', 'Health Deprivation and Disability Rank (where 1 is most deprived)', 'Health Deprivation and Disability Decile (where 1 is most deprived 10% of LSOAs)', 'Crime Rank (where 1 is most deprived)', 'Crime Decile (where 1 is most deprived 10% of LSOAs)', 'Barriers to Housing and Services Rank (where 1 is most deprived)', 'Barriers to Housing and Services Decile (where 1
# ...
