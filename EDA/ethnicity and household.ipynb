# %%
import pandas as pd
import matplotlib.pyplot as plt
import geopandas as gpd

ethnicity = pd.read_parquet("../processed_data/ethnicity_index.parquet") # discard, in LSOA data file
ethnicity
# Out:
#     Lower tier local authorities Code Lower tier local authorities  \
# 0                           E09000002         Barking and Dagenham
# 1                           E09000002         Barking and Dagenham
# 2                           E09000002         Barking and Dagenham
# 3                           E09000002         Barking and Dagenham
# 4                           E09000002         Barking and Dagenham
# ..                                ...                          ...
# 635                         E09000033                  Westminster
# 636                         E09000033                  Westminster
# 637                         E09000033                  Westminster
# 638                         E09000033                  Westminster
# 639                         E09000033                  Westminster
#
#      Ethnic group (20 categories) Code  \
# 0                                   -8
# 1                                    1
# 2                                    2
# ...

# %%
householdsize = pd.read_parquet("../processed_data/householdsize.parquet") # discard, covered in LSOA data
householdsize
# Out:
#     Number of households (thousands) [note 1] 2015 Estimate 2015 CV  \
# 0                                  One person           838       a
# 1                                  Two people           948       a
# 2                                Three people           597       a
# 3                                 Four people           519       a
# 4                                 Five people           209       b
# 5                          Six or more people           142       b
# 6                                 Six people             84       b
# 7                        Seven or more people            57       c
# 8                              All households         3.252       a
# 9   Average household size (number of people)          2,64       a
# 10                                       None          None    None
# 11                                       None          None    None
#
#    2015 CI+/- 2016 Estimate 2016 CV 2016 CI+/- 2017 Estimate 2017 CV  \
# ...
