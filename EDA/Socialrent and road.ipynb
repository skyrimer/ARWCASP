# %%
import pandas as pd
import matplotlib.pyplot as plt
import geopandas as gpd

social = pd.read_parquet("../processed_data/socialrent.parquet") # discard too little data
social
# Out:
#      Code   New Code                  Area 1996-97 1997-98 1998-99 1999-00  \
# 0    None       None                  None    None    None    None    None
# 1    00AA  E09000001        City of London   55,34   55,82   56,83   58,58
# 2    00AB  E09000002  Barking and Dagenham   39,71    42,1   44,43   49,68
# 3    00AC  E09000003                Barnet   52,11    52,6   52,59   55,35
# 4    00AD  E09000004                Bexley   53,02   58,52    LSVT    LSVT
# ..    ...        ...                   ...     ...     ...     ...     ...
# 272  None       None                  None    None    None    None    None
# 273  None       None                  None    None    None    None    None
# 274  None       None                  None    None    None    None    None
# 275  None       None                  None    None    None    None    None
# 276  None       None                  None    None    None    None    None
#
# ...

# %%
road = pd.read_parquet("../processed_data/roada.parquet") # discard too little data
road
# Out:
#         Code"  Region         Local Authority Trunk motorways  \
# 0   E09000002  London    Barking and Dagenham               0
# 1   E09000003  London                  Barnet              12
# 2   E09000004  London                  Bexley               0
# 3   E09000005  London                   Brent               0
# 4   E09000006  London                 Bromley               0
# 5   E09000007  London                  Camden               0
# 6   E09000001  London          City of London               0
# 7   E09000008  London                 Croydon               0
# 8   E09000009  London                  Ealing               0
# 9   E09000010  London                 Enfield            11,2
# 10  E09000011  London               Greenwich               0
# 11  E09000012  London                 Hackney               0
# 12  E09000013  London  Hammersmith and Fulham               0
# 13  E09000014  London                Haringey               0
# ...
