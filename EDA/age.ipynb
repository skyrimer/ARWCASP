# %% [markdown]
# # EDA for the age index

# %%
import pandas as pd
import matplotlib.pyplot as plt
import geopandas as gpd

age = pd.read_parquet("../processed_data/age_index.parquet") # discard the data, not per LSOA

big_dataset = pd.read_parquet("../processed_data/big_dataset.parquet")

# %%
age
# Out:
#                               Area     mnemonic  Aged 0 - 15     %  \
# 0    lacu2023:Barking and Dagenham  E09000002""        29239  27.0
# 1                  lacu2023:Barnet  E09000003""        42306  22.1
# 2                  lacu2023:Bexley  E09000004""        26278  21.7
# 3                   lacu2023:Brent  E09000005""        33412  19.8
# 4                 lacu2023:Bromley  E09000006""        33238  21.0
# ..                             ...          ...          ...   ...
# 97          lacu2023:Tower Hamlets    E09000030        56403  17.2
# 98         lacu2023:Waltham Forest    E09000031        55655  20.2
# 99             lacu2023:Wandsworth    E09000032        52651  15.9
# 100           lacu2023:Westminster    E09000033        26509  12.5
# 101                     gor:London    E12000007      1690386  18.9
#
#      Aged 16 - 64   %.1  Aged 65 and over   %.2  Aged 16 - 59/64   %.3  ...  \
# 0           70405  64.9              8763   8.1            70405  64.9  ...
# ...

# %%
big_dataset
# Out:
#       column_0                  column_1  \
# 0    MSOA Code                 MSOA Name
# 1    E02000001        City of London 001
# 2    E02000002  Barking and Dagenham 001
# 3    E02000003  Barking and Dagenham 002
# 4    E02000004  Barking and Dagenham 003
# ..         ...                       ...
# 980  E02000980           Westminster 021
# 981  E02000981           Westminster 022
# 982  E02000982           Westminster 023
# 983  E02000983           Westminster 024
# 984       None   MSOA average for London
#
#      Age Structure (2011 Census)|All Ages    0-15   16-29   30-44   45-64  \
# 0                                     NaN     NaN     NaN     NaN     NaN
# 1                                  7375.0   620.0  1665.0  2045.0  2010.0
# 2                                  6775.0  1751.0  1277.0  1388.0  1258.0
# 3                                 10045.0  2247.0  1959.0  2300.0  2259.0
# 4                                  6182.0  1196.0  1277.0  1154.0  1543.0
# ...
